# %% [markdown]
# # Live session 5.28.26 (Final live session of course)

# %% [markdown]
# ## Exception Handling

# %% [markdown]
# ### Common Standard Exceptions

# %%
- ValueError
- TypeError
- FileNotFoundError
- ZeroDivisionError
- IndexError

# %%
number = int("abc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 number = int("abc")
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# ### TypeError

# %%
total = 18 + '19'
total
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 total = 18 + '19'
#       2 total
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### FileNotFoundError

# %%
#- FileNotFoundError (File does not exist)
with open("comp661_file_exception_handling_module.txt", "r") as file:
    content = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 #- FileNotFoundError
# ----> 2 with open("comp661_file_exception_handling_module.txt", "r") as file:
#       3     content = file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'comp661_file_exception_handling_module.txt'

# %% [markdown]
# ### ZeroDivisionError

# %%
### ZeroDivisionError
Percentage = 10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 ### ZeroDivisionError
# ----> 2 Percentage = 10/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Index Error

# %%
### IndexError - Raised when trying to access a list index that doesn't exist.

pets = ["dog", "cat", "bird"]
pets[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 4
#       1 ### IndexError - Raised when trying to access a list index that doesn't exist.
#       2
#       3 pets = ["dog", "cat", "bird"]
# ----> 4 pets[3]
#
# IndexError: list index out of range
