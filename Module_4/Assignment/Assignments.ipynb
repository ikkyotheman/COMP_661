# %% [markdown]
# Question 1

# %%
count = 0
with open('file.txt') as file:
    for line in file:
        count += 1
print(count)
# Out:
# 4

# %% [markdown]
# Question 2

# %%
count = 0
fname = input('Enter the file name: ')
try:
    fhand = open(fname)
    for word in fhand.read().split():
        if len(word) == 5:
            count += 1
    print(f'There are {count} five letter words in the file')
except:
    print('File cannot be opened:', fname)
    exit()
# Out:
# There are 3 five letter words in the file

# %% [markdown]
# Question 3

# %%
import os

for file in os.listdir():
    print(file)
# Out:
# 260516_Kindrachuk_Peter_Q1.py
# 260516_Kindrachuk_Peter_Q5.py
# accounts.txt
# Assignments.ipynb
# 260516_Kindrachuk_Peter_Q1_Console.png
# file.txt
# 260516_Kindrachuk_Peter_Q2.py
# 260516_Kindrachuk_Peter_Q4_Console.png
# 260516_Kindrachuk_Peter_Q2_Console.png
# 260516_Kindrachuk_Peter_Q3_Console.png
# 260516_Kindrachuk_Peter_Q3.py
# 260516_Kindrachuk_Peter_Q4.py
# myaccounts.txt
# 260516_Kindrachuk_Peter_Q6.py

# %% [markdown]
# Question 4

# %%
fname = input('Enter the file name: ')
try:
    fhand = open(fname)
    for line in fhand:
        print(line, end='')
except:
    print('File cannot be opened:', fname)
    exit()
# Out:
# This is a test file
# Hello Student
# Testing 1,2,3 - testing !
# Python rocks !

# %% [markdown]
# Question 5

# %%
with open('accounts.txt', 'w') as file:
    file.writelines([
        '100 Mary 34.58\n',
        '200 Alison 345.67\n',
        '300 Marc 3.00\n',
        '400 Zoltar -32.16\n'
        '500 Kathleen 24.32\n'
    ])

# %% [markdown]
# Question 6

# %%
import os

with open('accounts.txt') as file:
    contents = file.read()

# update the name 'Zoltar' to 'Robert'
contents = contents.replace('Zoltar', 'Robert')

# create a tempfile with the new data
with open('tempfile.txt', 'w') as temp:
    temp.write(contents)

# Remove the original accounts.txt
os.remove('accounts.txt')

# Rename tempfile to myaccounts.txt
os.rename('tempfile.txt', 'myaccounts.txt')
