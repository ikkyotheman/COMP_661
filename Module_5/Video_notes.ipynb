# %% [markdown]
# # Module 5 - Exception handling

# %% [markdown]
# As you can see in the example below.

# %%
number = int(input('Enter an integer: '))
print('You entered a valid integer of ' + str(number) + '.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 number = int(input('Enter an integer: '))
#       2 print('You entered a valid integer of ' + str(number) + '.')
#
# ValueError: invalid literal for int() with base 10: 'five'

# %% [markdown]
# 'try and except' are a way to do exception handling

# %%
try:
    number = int(input('Enter an integer: '))
    print('You entered a valid integer of ' + str(number) + '.')
except ValueError:
    print('You entered an invalid integer. Please try again')
# Out:
# You entered an invalid integer. Please try again

# %% [markdown]
# The bottom will catch any error (not just ValueError) however it is better practice
# to be more specific

# %%
try:
    number = int(input('Enter an integer: '))
    print('You entered a valid integer of ' + str(number) + '.')
except:
    print('You entered an invalid integer. Please try again')
# Out:
# You entered an invalid integer. Please try again

# %%
## try / except — Handling Multiple Exceptions

def divide_numbers():
    numerator = int(input("Enter the numerator: "))
    denominator = int(input("Enter the denominator: "))
    result = numerator / denominator
    return result

except ZeroDivisionError:
    print("Error : You cannot divide by zero !")

except ValueError:
    print("Error : Invalid Input ! please enter numeric values")

except Exception as e:
    print(f"an unexpected error occured: {e}")
# Out:
#   Cell In[1], line 9
#     except ZeroDivisionError:
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Raise Exceptions

# %%
def calculate_age(year_born):
    current_year = 2026
    age = current_year - year_born
    if year_born > current_year:
        raise ValueError('Birth Year should not be in the future!')
    return age

# %%
try:
    print(calculate_age(2036))
except ValueError as error:
    print(f'Catch : {error}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 try:
#       2     print(calculate_age(2036))
# ----> 3 except ValueError as error:
#       4     print(f'Catch : {error}')
#
# NameError: name 'calculate_age' is not defined
