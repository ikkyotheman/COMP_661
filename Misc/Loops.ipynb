# %% [markdown]
# ### The While statement

# %%
n = 5
while n > 0:
    print(n)
    n = n - 1
print('Blastoff!')
# Out:
# 5
# 4
# 3
# 2
# 1
# Blastoff!

# %%
x=1
while x < 10:
    print(f'This is instance', x)
    x+=1
print('This is the 10th instance!')
# Out:
# This is instance 1
# This is instance 2
# This is instance 3
# This is instance 4
# This is instance 5
# This is instance 6
# This is instance 7
# This is instance 8
# This is instance 9
# This is the 10th instance!

# %% [markdown]
# Notice on the example below, the first character of the input is compared using line[0]

# %%
while True:
    line = input('> ')
    if line[0] == '#':
        continue
    if line == 'done':
        break
    print(line)
print('Done!')
# Out:
# hey
# don't
# Done!

# %%
count = 0
for itervar in [3, 41, 12, 9, 74, 15]:
    count = count + 1
print('Count: ', count)
# Out:
# Count:  6

# %%
largest = None
print('Before:', largest)
for itervar in [3, 41, 12, 9, 74, 15]:
    if largest is None or itervar > largest :
        largest = itervar
    print('Loop:', itervar, largest)
print('Largest:', largest)
# Out:
# Before: None
# Loop: 3 3
# Loop: 41 41
# Loop: 12 41
# Loop: 9 41
# Loop: 74 74
# Loop: 15 74
# Largest: 74

# %%
smallest = None
print('Before:', smallest)
for itervar in [3, 41, 12, 9, 74, 15]:
    if smallest is None or itervar < smallest:
        smallest = itervar
    print('Loop:', itervar, smallest)
print('Smallest:', smallest)
# Out:
# Before: None
# Loop: 3 3
# Loop: 41 3
# Loop: 12 3
# Loop: 9 3
# Loop: 74 3
# Loop: 15 3
# Smallest: 3
